# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import Imputer

source = 'wine-reviews/winemag-data-130k-v2.csv'

df = pd.read_csv(source, encoding='utf-8')

# %% [markdown]
# # Data-4-Dummies
#
# ## Intended features:
# * High-level Overviews (Descriptions of Data & Columns)
# * Data Preprocessing (Imputation, Null-Removal)
# * Basic Feature Engineering
# * Basic Predictive Analysis (Based on user-selected features)
#
# ### Steps of Data Science
# 1) Display initial data<br>
# 2) Grab information on the size, columns, and number of null-objects in dataframe<br>
# 3) Null removel<br>
# 4) Imputation<br>
# 5) Imputation<br>

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
# All column info
def get_dataframe_data(df):
    # Create Dataframe on all column info
    all_data = pd.DataFrame(
    {'columns': df.columns,
     'type': df.dtypes,
     'count_of_nans': df.isnull().sum()
    }).set_index('columns')
    
    # Booleon if column has NaN's
    all_data['no_nans'] = all_data['count_of_nans'].map(lambda x: x > 0)
    
    df_len = len(df.index)
    
    return all_data, df_len

# %%
all_data, df_len = get_dataframe_data(df)
#print(df_len)
#all_data

# %%
def null_removel(df):
    # Drop row if any value is NaN
    df.dropna()
    
    # Drop row only if all columns are NaN
    df.dropna(how='all')
    
    # Drop row if NaN within specific column name
    df.dropna(subset = ['column_name'])


def imputation(df):
    # Fill NaN's with the mean of the column
    df['price'].fillna(df['price'].mean(), inplace=True)
    
    # Fill NaN's with the medium of the column
    df['price'].fillna(df['price'].medium(), inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...
